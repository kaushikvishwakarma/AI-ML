# %%
import pandas as pd;

# %%
#2main datatypes
series=pd.Series(["BMW","OUDI","Lambo","ferrari"])

# %%
series
# Out:
# 0        BMW
# 1       OUDI
# 2      Lambo
# 3    ferrari
# dtype: object

# %%
color=pd.Series(["red","Blue","White"])
color
# Out:
# 0      red
# 1     Blue
# 2    White
# dtype: object

# %%
car_data=pd.DataFrame({"car make":series,"colour":color})
car_data
# Out:
#   car make colour
# 0      BMW    red
# 1     OUDI   Blue
# 2    Lambo  White
# 3  ferrari    NaN

# %%
#import Data
car_sales=pd.read_csv("car-sales.csv");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#exporting DataFrame
car_sales.to_csv("Export-carsales.csv",index=False)

# %%
expo=pd.read_csv("Export-carsales.csv")

# %%
expo
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
#Attribute
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_column=car_sales.columns
car_column
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.reset_index
# Out:
# <bound method DataFrame.reset_index of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %% [markdown]
# ## Viewing and selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc &.iloc
animals=pd.Series(["cat","dog","Cow","panda","snake","bird"],index=[0,3,9,8,3,9])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9      Cow
# 8    panda
# 3    snake
# 9     bird
# dtype: object

# %%
#loc refers to index 
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 9     Cow
# 9    bird
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9      Cow
# 8    panda
# 3    snake
# 9     bird
# dtype: object

# %%
#.iloc-->position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>=150000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Remove price column symbols
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','',regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\vkaus\AppData\Local\Temp\ipykernel_10848\4228985597.py:2: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','',regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
# Column from series
seats_column=pd.Series([5,5,5,5,5,5])
#New column called seats
car_sales["Seats"]=seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)
# Out:
# C:\Users\vkaus\AppData\Local\Temp\ipykernel_10848\3224728129.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["Seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
#Column from Python list
fuel_economy=[7.5,9.2,5.0,9.6,8.7,5.2,4.8,7.9,7.4,5.9]
car_sales["Fuel per 100KM"]=fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             5.2
# 6   honda   Blue          45698      4   750000    5.0             4.8
# 7   honda   Blue          54738      4   700000    5.0             7.9
# 8  toyota  White          60000      4   625000    5.0             7.4
# 9  nissan  White          31600      4   970000    5.0             5.9

# %%
 car_sales["Total Fuel Used(L)"]=car_sales["Odometer (KM)"]/100 *car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             5.2
# 6   honda   Blue          45698      4   750000    5.0             4.8
# 7   honda   Blue          54738      4   700000    5.0             7.9
# 8  toyota  White          60000      4   625000    5.0             7.4
# 9  nissan  White          31600      4   970000    5.0             5.9
#
#    Total Fuel Used(L)
# 0           11253.225
# 1            8086.708
# 2            1627.450
# 3            1073.184
# 4           18539.265
# 5            5159.076
# 6            2193.504
# ...

# %%
car_sales.drop("Total Fuel Used(L)",axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             5.2
# 6   honda   Blue          45698      4   750000    5.0             4.8
# 7   honda   Blue          54738      4   700000    5.0             7.9
# 8  toyota  White          60000      4   625000    5.0             7.4
# 9  nissan  White          31600      4   970000    5.0             5.9

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 8  toyota  White          60000      4   625000    5.0             7.4
# 9  nissan  White          31600      4   970000    5.0             5.9
# 4  nissan  White         213095      4   350000    5.0             8.7
# 7   honda   Blue          54738      4   700000    5.0             7.9
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 5  toyota  Green          99213      4   450000    5.0             5.2
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 6   honda   Blue          45698      4   750000    5.0             4.8
#
#    Total Fuel Used(L)
# 2            1627.450
# 8            4440.000
# 9            1864.400
# 4           18539.265
# 7            4324.302
# 3            1073.184
# 5            5159.076
# ...

# %%
car_sales_shuffled=car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4   500000    5.0             9.2
# 5  toyota  Green          99213      4   450000    5.0             5.2
# 0  toyota  White         150043      4   400000    5.0             7.5
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 9  nissan  White          31600      4   970000    5.0             5.9
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 8  toyota  White          60000      4   625000    5.0             7.4
# 6   honda   Blue          45698      4   750000    5.0             4.8
# 4  nissan  White         213095      4   350000    5.0             8.7
# 7   honda   Blue          54738      4   700000    5.0             7.9
#
#    Total Fuel Used(L)
# 1            8086.708
# 5            5159.076
# 0           11253.225
# 2            1627.450
# 9            1864.400
# 3            1073.184
# 8            4440.000
# ...

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0   honda    Red          87899      4   500000    5.0             9.2
# 1  toyota  Green          99213      4   450000    5.0             5.2
# 2  toyota  White         150043      4   400000    5.0             7.5
# 3  toyota   Blue          32549      3   700000    5.0             5.0
# 4  nissan  White          31600      4   970000    5.0             5.9
# 5     bmw  Black          11179      5  2200000    5.0             9.6
# 6  toyota  White          60000      4   625000    5.0             7.4
# 7   honda   Blue          45698      4   750000    5.0             4.8
# 8  nissan  White         213095      4   350000    5.0             8.7
# 9   honda   Blue          54738      4   700000    5.0             7.9
#
#    Total Fuel Used(L)
# 0            8086.708
# 1            5159.076
# 2           11253.225
# 3            1627.450
# 4            1864.400
# 5            1073.184
# 6            4440.000
# ...

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   400000    5.0             7.5
# 1   honda    Red      54936.875      4   500000    5.0             9.2
# 2  toyota   Blue      20343.125      3   700000    5.0             5.0
# 3     bmw  Black       6986.875      5  2200000    5.0             9.6
# 4  nissan  White     133184.375      4   350000    5.0             8.7
# 5  toyota  Green      62008.125      4   450000    5.0             5.2
# 6   honda   Blue      28561.250      4   750000    5.0             4.8
# 7   honda   Blue      34211.250      4   700000    5.0             7.9
# 8  toyota  White      37500.000      4   625000    5.0             7.4
# 9  nissan  White      19750.000      4   970000    5.0             5.9
#
#    Total Fuel Used(L)
# 0           11253.225
# 1            8086.708
# 2            1627.450
# 3            1073.184
# 4           18539.265
# 5            5159.076
# 6            2193.504
# ...

# %%
#Try it ,run code
